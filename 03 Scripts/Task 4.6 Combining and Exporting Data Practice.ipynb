# %% [markdown]
# # 4.6 Combining and Exporting Data

# %% [markdown]
# **This script contains the following points:**
#
# **1. Create data to experiment on**
#
# **2. Concatenate dataframes**
#
# **3. Append data**
#
# **4. Merge data**
#
# **5. Merge instacart data with orders_products_prior**
#
# **6. Export orders_products_combined as PKL**

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# **1. Create data to experiment on**

# %%
# Define a dictionary containing January 2020 data
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %%
#Convert the dictionary into dataframe
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# **2. Concatenate dataframes**

# %%
# Create a list that contains our dataframes
frames = [df, df_1]

# %%
# Check the output
frames
# Out:
# [  customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
#  0        6732  Jan-20               0                  1                10
#  1         767  Jan-20              13                  2                 5
#  2         890  Jan-20               3                 10                 1
#  3         635  Jan-20               4                  0                 7,
#    customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
#  0        6732  Feb-20               0                  2                15
#  1         767  Feb-20              10                  4                 3
#  2         890  Feb-20               5                 14                 2
#  3         635  Feb-20               3                  0                 6]

# %%
# Check the data types to be sure it is a list
type(frames)
# Out:
# list

# %%
# Concatenate the dataframes using default options and check output
df_concat = pd.concat(frames)
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Concatenate the dataframes using the axis = 1 --> create a wide format as an output and check output
df_concat = pd.concat(frames, axis = 1)
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# **3. Append data**

# %%
#append data
df_appended = df.append(df_1)
df_appended
# Out:
# C:\Users\ddgal\AppData\Local\Temp\ipykernel_22848\1538074913.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = df.append(df_1)
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Create data with different columns from df
data3 = {'customer_id':['6732', '767', '890', '635'], 
        'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'], 
        'days_purchased_on':[0, 13, 3, 4]}

# %%
# Convert to dataframe
df_2 = pd.DataFrame(data3,index=[0, 1, 2, 3])
df_2
# Out:
#   customer_id   month  days_purchased_on
# 0        6732  Jan-20                  0
# 1         767  Jan-20                 13
# 2         890  Jan-20                  3
# 3         635  Jan-20                  4

# %%
# Create a new dataset combining df and df_2
df_append_test = df.append(df_2)
# Out:
# C:\Users\ddgal\AppData\Local\Temp\ipykernel_22848\2324322743.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_test = df.append(df_2)

# %%
df_append_test
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20             0.0                1.0              10.0
# 1         767  Jan-20            13.0                2.0               5.0
# 2         890  Jan-20             3.0               10.0               1.0
# 3         635  Jan-20             4.0                0.0               7.0
# 0        6732  Jan-20             NaN                NaN               NaN
# 1         767  Jan-20             NaN                NaN               NaN
# 2         890  Jan-20             NaN                NaN               NaN
# 3         635  Jan-20             NaN                NaN               NaN
#
#    days_purchased_on
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 0                0.0
# 1               13.0
# 2                3.0
# 3                4.0

# %% [markdown]
# **4. Merge data**

# %%
#merge df and df_1 based on customer_id and check output
df_merged = df.merge(df_1, on = 'customer_id')
df_merged
# Out:
#   customer_id month_x  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x month_y  purchased_meat_y  purchased_alcohol_y  \
# 0                  10  Feb-20                 0                    2
# 1                   5  Feb-20                10                    4
# 2                   1  Feb-20                 5                   14
# 3                   7  Feb-20                 3                    0
#
#    purchased_snacks_y
# 0                  15
# 1                   3
# 2                   2
# 3                   6

# %%
#merge df and df_2 using customer_id and month as a keys and check output 
df_merged = df.merge(df_2, on = ['customer_id', 'month'])
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 13
# 2                  3
# 3                  4

# %%
# Merge df and df_2 using customer_id and month as a keys, add a merge flag, check output
df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 13   both
# 2                  3   both
# 3                  4   both

# %% [markdown]
# **5. Merge instacart data with orders_products_prior**

# %%
#set path
path = r'C:\Users\ddgal\OneDrive\Desktop\Career Foundry Tasks\Data Immersion\22-03-2023 Instacart Basket Analysis'

# %%
#import df_ords
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
#import df_ords_prior
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
#check outputs
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#check outputs
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#check data type
df_ords_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
#change data type of order_id of df_ords_prior to str to match that of df_ords
df_ords_prior['order_id'] = df_ords_prior['order_id'].astype('str')

# %%
df_ords_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           object
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(3), object(1)
# memory usage: 989.8+ MB

# %%
#check shapea
df_ords.shape
# Out:
# (1048575, 6)

# %%
#check shape
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#merge both df_ords and df_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#check output
df_merged_large.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2539329        1             1                   2                  8
# 2  2539329        1             1                   2                  8
# 3  2539329        1             1                   2                  8
# 4  2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          9927471
# left_only           0
# right_only          0
# Name: _merge, dtype: int64
